# %%
import sys 
import scanpy as sc
import GAIA as ga
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 import scanpy as sc
# ----> 3 import GAIA as scf
#
# ModuleNotFoundError: No module named 'GAIA'

# %%
adata = sc.read_h5ad('example.h5ad')

# %% [markdown]
# ## input raw UMI counts data

# %%
ga.tl.fisher_PCA(adata)

## output a embedding matrix in adata.obsm['X_scFisher]

# %%
ga.pl.embedding(adata , color = 'type', basis='X_scFisher')
# Out:
# /home/jinpucai/miniconda3/envs/gaia/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
ga.tl.gene_module(adata)

## output up and down gene modules ranked by scFisher
# Out:
# finished gene module

# %%
ga.pl.module(adata,color = 'type', components=1)
# Out:
# /home/jinpucai/miniconda3/envs/gaia/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
